# %% [markdown]
# # Python Basic
#
# Date: 24/09/2024
#
# URL: https://docs.python.org/es/3/tutorial/index.html

# %%
tax = 12.5 / 100
price = 100.5

price_with_tax = price * tax

print(price_with_tax)
print(round(price_with_tax, 2))
# Out:
# 12.5625
# 12.56

# %% [markdown]
# ### Caracteres de escape

# %%
# use \' to escape the single quote...
print('doesn\'t')

# ...or use double quotes instead
print("doesn't")

print('"Yes," they said.')

print("\"Yes,\" they said.")

print('"Isn\'t," they said.')
# Out:
# doesn't
# doesn't
# "Yes," they said.
# "Yes," they said.
# "Isn't," they said.

# %% [markdown]
# ### Control de flujo

# %%
x = int(input("Please enter an integer: "))

if x < 0:
    x = 0
    print('Negative changed to zero')
elif x == 0:
    print('Zero')
elif x == 1:
    print('Single')
else:
    print('More')


print(f"x = {x}")
# Out:
# Please enter an integer: 0
# Zero
# x = 0

# %%
status = int(input('Number: '))

match status:
    case 400:
        msg = "Bad request"
    case 404:
        msg = "Not found"
    case 418:
        msg = "I'm a teapot"
    case _:
        msg = "Something's wrong with the internet"

print(msg)
# Out:
# Number: 418
# I'm a teapot

# %% [markdown]
# ### Bucles

# %%
# range(inicio, fin, incremento)
# range(inicio, fin)
# range(fin)

print(list(range(4)))
# Out:
# [0, 1, 2, 3]

# %%
# [0, 18) de 2 en 2:

for i in range(0, 18, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16

# %%
cadena = "esternocleidomastoideo"

for i in range(len(cadena)):
    print(cadena[i])
# Out:
# e
# s
# t
# e
# r
# n
# o
# c
# l
# e
# i
# d
# o
# m
# a
# s
# t
# o
# i
# d
# e
# o

# %%
# Un poquito de Fibonacci y selección simultánea

a, b = 0, 1

while a < 10:
    print(a)
    a, b = b, a+b
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
# Un bucle un poco mas complicado

# Create a sample collection
users = {'Hans': 'active', 'Éléonore': 'inactive', '景太郎': 'active'}

# Strategy:  Iterate over a copy
for user, status in users.copy().items():
    if status == 'inactive':
        del users[user]

print(users)

# Strategy:  Create a new collection
active_users = {}
for user, status in users.items():
    if status == 'active':
        active_users[user] = status

print(active_users)
# Out:
# {'Hans': 'active', '景太郎': 'active'}
# {'Hans': 'active', '景太郎': 'active'}
