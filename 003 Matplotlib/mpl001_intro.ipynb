# %% [markdown]
# UPDATED: 15/10/2024
#
# URL: https://matplotlib.org/stable/users/explain/quick_start.html

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# %% [markdown]
# Vamos a dibujar la función y = 2 * x

# %%
x = [i for i in range(5)]
x
# Out:
# [0, 1, 2, 3, 4]

# %%
datos = pd.DataFrame(x, columns = ['ejex'])

# %%
datos['ejey'] = datos.ejex * 2
datos.head()
# Out:
#    ejex  ejey
# 0     0     0
# 1     1     2
# 2     2     4
# 3     3     6
# 4     4     8

# %%
fig, ax = plt.subplots()

ax.plot('ejex', 'ejey', data = datos)

plt.show()

# %% [markdown]
# Otra forma de usarlo es con dos listas

# %%
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

fig, ax = plt.subplots()
ax.plot(x, y)

plt.show()

# %% [markdown]
# Añadir títulos y texto

# %%
fig, ax = plt.subplots()
ax.plot('ejex', 'ejey', data = datos,  scalex=False,  scaley=False)
ax.set_title("y = 2 * x")

ax.set_xlim(0,10)
ax.set_ylim(0,10)

ax.legend()
ax.set_xlabel("x")
ax.set_ylabel("y")

plt.show()

# %% [markdown]
# Lo mismo de otra forma

# %%
fig, ax = plt.subplots()

ax.plot(datos.ejex, datos.ejey,  scalex=False,  scaley=False)

ax.set_title("y = 2 * x")
ax.set_xlabel("x")
ax.set_ylabel("y")

plt.show()
