# %% [markdown]
# # Ejercicios sobre MatPlotLib

# %% [markdown]
# UPDATED: 17/10/2024

# %% [markdown]
# E001. Para el fichero "statage.csv", muestra en una sola gráfica la altura mediana de niños y niñas en función de la edad.
#
# Tiene que ser parecido a esto: http://theinformationdiet.blogspot.com/2011/11/average-height-of-american-boys-and.html

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# %%
# para google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# para google colab:
# path = "../datos/"
path = "/content/drive/My Drive/Clara del Rey/BIG DATA/Programacion/FTP/000 Datos/"
datos = pd.read_csv(path + "statage.csv", sep = ",")

# %%
datos.head(2)
# Out:
#    Sex  Agemos         L          M         S         P3         P5  \
# 0    1    24.0  0.941524  86.452201  0.040322  79.910844  80.729773
# 1    1    24.5  1.007208  86.861609  0.040396  80.260371  81.088685
#
#          P10        P25        P50        P75        P90        P95        P97
# 0  81.991714  84.102892  86.452201  88.805249  90.926191  92.196879  93.022654
# 1  82.364010  84.494706  86.861609  89.228048  91.357530  92.631767  93.459230

# %%
datos.describe()
# Out:
#               Sex      Agemos           L           M           S          P3  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean     1.500000  132.000000    0.808462  140.116281    0.044047  128.575191
# std      0.500574   62.994909    0.604547   26.822148    0.003448   24.579871
# min      1.000000   24.000000   -0.390918   84.975555    0.039636   78.437542
# 25%      1.000000   77.500000    0.416526  118.221948    0.040775  108.501310
# 50%      1.500000  132.000000    0.902484  143.712682    0.043780  130.586815
# 75%      2.000000  186.500000    1.172497  162.950547    0.046628  150.667754
# max      2.000000  240.000000    2.235834  176.849232    0.050560  163.333333
#
#                P5         P10         P25         P50         P75         P90  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean   130.017479  132.240969  135.964641  140.116281  144.285535  148.055014
# ...

# %%
datos["Sex"].unique()
# Out:
# array([1, 2])

# %%
chicas = datos[datos['Sex'] == 1]
chicas.head(3)
# Out:
#    Sex  Agemos         L          M         S         P3         P5  \
# 0    1    24.0  0.941524  86.452201  0.040322  79.910844  80.729773
# 1    1    24.5  1.007208  86.861609  0.040396  80.260371  81.088685
# 2    1    25.5  0.837251  87.652473  0.040578  81.005294  81.834452
#
#          P10        P25        P50        P75        P90        P95        P97
# 0  81.991714  84.102892  86.452201  88.805249  90.926191  92.196879  93.022654
# 1  82.364010  84.494706  86.861609  89.228048  91.357530  92.631767  93.459230
# 2  83.113871  85.258877  87.652473  90.056755  92.229661  93.534066  94.382780

# %%
chicos = datos[datos['Sex'] == 2]
chicos.head(3)
# Out:
#      Sex  Agemos         L          M         S         P3         P5  \
# 218    2    24.0  1.072449  84.975555  0.040791  78.437542  79.259820
# 219    2    24.5  1.051273  85.397317  0.040860  78.821333  79.647769
# 220    2    25.5  1.041951  86.290263  0.041142  79.601976  80.442257
#
#            P10        P25        P50        P75        P90        P95  \
# 218  80.524765  82.635236  84.975555  87.311214  89.409512  90.663549
# 219  80.919463  83.042132  85.397317  87.749175  89.863158  91.127070
# 220  81.735410  83.894303  86.290263  88.683435  90.835048  92.121676
#
#            P97
# 218  91.477287
# 219  91.947412
# 220  92.956850

# %%
fig, ax = plt.subplots()

# Graficar (Agemos en el eje X y M en el eje Y)
ax.plot('Agemos', 'M', data = chicas)
ax.plot('Agemos', 'M', data = chicos)

plt.show()

# %%
# Solucion profe:

fig, ax = plt.subplots()

ax.plot('Agemos', 'M', data = datos[datos.Sex == 1], label = 'Niños')
ax.plot('Agemos', 'M', data = datos[datos.Sex == 2], label = 'Niñas')

ax.set_title("Altura en función de la edad")
ax.set_xlabel("Edad en meses")
ax.set_ylabel("Altura en cm")
ax.legend()

plt.show()

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots()

# Graficar chicas (Agemos en el eje X y M en el eje Y)
ax.plot(chicas['Agemos'], chicas['M'], label='Chicas', color='pink')

# Graficar chicos (Agemos en el eje X y M en el eje Y)
ax.plot(chicos['Agemos'], chicos['M'], label='Chicos', color='blue')

# Añadir etiquetas a los ejes
ax.set_xlabel('age (months)')
ax.set_ylabel('height (cm)')

# Añadir título
ax.set_title('Age vs Months for boys (chicos) and girls (chicas)')

# Añadir leyenda
ax.legend()

# Activar la cuadrícula (grid)
ax.grid(True, linestyle='--', linewidth=0.5)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# E002. Para el fichero "statage.csv", muestra una figure con dos subplots, uno para niños y otro para niñas. En cada uno hay que poner altura mediana, percentil 25 y percentil 75 para cada edad.

# %%
# los argumentos indican que habrá dos filas y una columna de subplots
fig, ax = plt.subplots(nrows = 1, ncols = 2, sharey=True)


fig.suptitle("Figure con 2 subplots")


# Forma 1
# Plotear M, P25 y P75 para chicas en el primer subplot
ax[0].plot(chicas['Agemos'], chicas['M'], label="M", color='blue')
ax[0].plot(chicas['Agemos'], chicas['P25'], label="P25", color='green', linestyle='--')
ax[0].plot(chicas['Agemos'], chicas['P75'], label="P75", color='orange', linestyle='--')

ax[0].legend()
ax[0].set_title('Chicas')
ax[0].set_xlabel('Edad (meses)')
ax[0].set_ylabel('Altura (cm)')
ax[0].grid(True)



# Forma 2
# Plotear M, P25 y P75 para chicos en el segundo subplot

# el parametro 'Agemos' es data['Agemos'] siendo data=datos[datos.Sex==2][]
# el parametro 'M' es data['M'] siendo data=datos[datos.Sex==2][]
ax[1].plot('Agemos', 'M', data=datos[datos.Sex==2], label="Mediana", color='blue')
ax[1].plot('Agemos', 'P25', data=datos[datos.Sex==2], label="P25", color='green', linestyle='--')
ax[1].plot('Agemos', 'P75', data=datos[datos.Sex==2], label="P75", color='orange', linestyle='--')

ax[1].legend()
ax[1].set_title('Chicos')
ax[1].set_xlabel('Edad (meses)')
ax[0].set_ylabel('Altura (cm)')
ax[1].grid(True)


plt.show()
