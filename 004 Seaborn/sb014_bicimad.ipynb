# %%
# 26/11/2024
import pandas as pd
import seaborn as sns

# %% [markdown]
# Hay filas vacías en el fichero

# %%
# google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/My Drive/Clara del Rey/BIG DATA/Programacion/FTP/000 Datos/"
datos = pd.read_csv(path + "trips_23_01_January.csv", sep = ";")
print(len(datos))
datos.head()
# Out:
#         fecha  idBike  fleet  trip_minutes  \
# 0         NaN     NaN    NaN           NaN
# 1  2023-01-01  3728.0    1.0         35.10
# 2         NaN     NaN    NaN           NaN
# 3  2023-01-01  4465.0    1.0          8.33
# 4         NaN     NaN    NaN           NaN
#
#                                   geolocation_unlock  \
# 0                                                NaN
# 1  {'type': 'Point', 'coordinates': [-3.6954403, ...
# 2                                                NaN
# 3  {'type': 'Point', 'coordinates': [-3.7081246, ...
# 4                                                NaN
#
#                     address_unlock          unlock_date locktype unlocktype  \
# 0                              NaN                  NaN      NaN        NaN
# 1  'Plaza de Alonso Martínez nº 5'  2023-01-01T00:01:08  STATION    STATION
# 2                              NaN                  NaN      NaN        NaN
# ...

# %% [markdown]
# Eliminar las filas con nulos

# %%
datos.dropna(inplace=True)
print(len(datos))
datos.head()
# Out:
# 294814
#         fecha  idBike  fleet  trip_minutes  \
# 1  2023-01-01  3728.0    1.0         35.10
# 3  2023-01-01  4465.0    1.0          8.33
# 5  2023-01-01  7659.0    1.0         11.27
# 7  2023-01-01  7604.0    1.0          6.97
# 9  2023-01-01  6618.0    1.0          9.62
#
#                                   geolocation_unlock  \
# 1  {'type': 'Point', 'coordinates': [-3.6954403, ...
# 3  {'type': 'Point', 'coordinates': [-3.7081246, ...
# 5  {'type': 'Point', 'coordinates': [-3.71019, 40...
# 7  {'type': 'Point', 'coordinates': [-3.7133412, ...
# 9  {'type': 'Point', 'coordinates': [-3.71019, 40...
#
#                     address_unlock          unlock_date locktype unlocktype  \
# 1  'Plaza de Alonso Martínez nº 5'  2023-01-01T00:01:08  STATION    STATION
# 3    'Plaza de Santo Domingo nº 1'  2023-01-01T00:01:45  STATION    STATION
# 5            'Calle Galileo nº 63'  2023-01-01T00:03:24  STATION    STATION
# ...

# %% [markdown]
# Ejercicio: muestra un gráfico de scatter que en el eje x tenga la hora de inicio y en el y la duración del trayecto.

# %%
datos["hora"] = datos.unlock_date.str.slice(11,13)
datos.head()
# Out:
#         fecha  idBike  fleet  trip_minutes  \
# 1  2023-01-01  3728.0    1.0         35.10
# 3  2023-01-01  4465.0    1.0          8.33
# 5  2023-01-01  7659.0    1.0         11.27
# 7  2023-01-01  7604.0    1.0          6.97
# 9  2023-01-01  6618.0    1.0          9.62
#
#                                   geolocation_unlock  \
# 1  {'type': 'Point', 'coordinates': [-3.6954403, ...
# 3  {'type': 'Point', 'coordinates': [-3.7081246, ...
# 5  {'type': 'Point', 'coordinates': [-3.71019, 40...
# 7  {'type': 'Point', 'coordinates': [-3.7133412, ...
# 9  {'type': 'Point', 'coordinates': [-3.71019, 40...
#
#                     address_unlock          unlock_date locktype unlocktype  \
# 1  'Plaza de Alonso Martínez nº 5'  2023-01-01T00:01:08  STATION    STATION
# 3    'Plaza de Santo Domingo nº 1'  2023-01-01T00:01:45  STATION    STATION
# 5            'Calle Galileo nº 63'  2023-01-01T00:03:24  STATION    STATION
# ...

# %%
datos.describe()
# Out:
#               idBike          fleet   trip_minutes  station_unlock  \
# count  294814.000000  294814.000000  294814.000000   294814.000000
# mean     5978.118481       1.002106      23.402209      128.452095
# std      2024.665779       0.045847     245.054685       75.493595
# min         1.000000       1.000000       0.000000        1.000000
# 25%      5015.000000       1.000000       0.670000       58.000000
# 50%      6576.000000       1.000000       8.670000      129.000000
# 75%      7546.000000       1.000000      14.580000      192.000000
# max      8090.000000       2.000000   40327.080000      270.000000
#
#          dock_unlock   station_lock      dock_lock
# count  294814.000000  294814.000000  294814.000000
# mean       12.378517     128.455182      12.398214
# std         7.560556      75.607796       7.588720
# min         1.000000       1.000000       1.000000
# 25%         5.000000      58.000000       5.000000
# 50%        12.000000     129.000000      12.000000
# ...

# %% [markdown]
# Filtramos trayectos de menos de dos horas y mayores de cinco minutos

# %%
datos = datos.query('trip_minutes < 120 & trip_minutes > 0')
datos.head()
# Out:
#         fecha  idBike  fleet  trip_minutes  \
# 1  2023-01-01  3728.0    1.0         35.10
# 3  2023-01-01  4465.0    1.0          8.33
# 5  2023-01-01  7659.0    1.0         11.27
# 7  2023-01-01  7604.0    1.0          6.97
# 9  2023-01-01  6618.0    1.0          9.62
#
#                                   geolocation_unlock  \
# 1  {'type': 'Point', 'coordinates': [-3.6954403, ...
# 3  {'type': 'Point', 'coordinates': [-3.7081246, ...
# 5  {'type': 'Point', 'coordinates': [-3.71019, 40...
# 7  {'type': 'Point', 'coordinates': [-3.7133412, ...
# 9  {'type': 'Point', 'coordinates': [-3.71019, 40...
#
#                     address_unlock          unlock_date locktype unlocktype  \
# 1  'Plaza de Alonso Martínez nº 5'  2023-01-01T00:01:08  STATION    STATION
# 3    'Plaza de Santo Domingo nº 1'  2023-01-01T00:01:45  STATION    STATION
# 5            'Calle Galileo nº 63'  2023-01-01T00:03:24  STATION    STATION
# ...

# %%
sns.catplot(datos, x = "hora", y = "trip_minutes")

# %%
datos = pd.read_csv(path + "trips_23_01_January.csv", sep = ";")
datos.dropna(inplace = True)
datos.trip_minutes = datos.trip_minutes.astype(float)
datos.head()
# Out:
#         fecha  idBike  fleet  trip_minutes  \
# 1  2023-01-01  3728.0    1.0         35.10
# 3  2023-01-01  4465.0    1.0          8.33
# 5  2023-01-01  7659.0    1.0         11.27
# 7  2023-01-01  7604.0    1.0          6.97
# 9  2023-01-01  6618.0    1.0          9.62
#
#                                   geolocation_unlock  \
# 1  {'type': 'Point', 'coordinates': [-3.6954403, ...
# 3  {'type': 'Point', 'coordinates': [-3.7081246, ...
# 5  {'type': 'Point', 'coordinates': [-3.71019, 40...
# 7  {'type': 'Point', 'coordinates': [-3.7133412, ...
# 9  {'type': 'Point', 'coordinates': [-3.71019, 40...
#
#                     address_unlock          unlock_date locktype unlocktype  \
# 1  'Plaza de Alonso Martínez nº 5'  2023-01-01T00:01:08  STATION    STATION
# 3    'Plaza de Santo Domingo nº 1'  2023-01-01T00:01:45  STATION    STATION
# 5            'Calle Galileo nº 63'  2023-01-01T00:03:24  STATION    STATION
# ...

# %% [markdown]
# Los valores execivamente altos de la druación para algunas filas hacen que sea difícil hacer un histograma.
# También la acumulación de menos de 5 minutos

# %%
datos = datos.query('trip_minutes < 120 & trip_minutes > 5')
sns.displot(
    datos,
    x = "trip_minutes",
    bins = 30
)
